# %% [markdown]
# <a href="https://colab.research.google.com/github/jlyajure/Family-App/blob/main/GPT-SoVITS-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👇 Just Click the Play Button (Run) and Wait for Public Gradio Link

# %%
# @title Do Everything For Me and Launch Gradio
# %cd /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# !conda install -c conda-forge gcc gxx ffmpeg cmake
# !conda install pytorch==2.1.1 torchvision==0.16.1 torchaudio==2.1.1 pytorch-cuda=11.8 -c pytorch -c nvidia

# !pip install pyyaml  # This addresses the ModuleNotFoundError for yaml
# !pip install numba==0.56.4  # Trying to install numba separately to see if it resolves the issue

# !pip install -r requirements.txt

# !python webui.py
# Out:
# /content
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.
# /content/GPT-SoVITS
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#   Using cached numba-0.56.4.tar.gz (2.4 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# Ignoring onnxruntime: markers 'platform_machine == "aarch64" or platform_machine == "arm64"' don't match your environment
# ...
#   File "/content/GPT-SoVITS/webui.py", line 1978
#     share=is_share,
#     ^^^^^^^^^^^^^^
# ...

# %%
# 1. Limpiar el desorden del 'share' y activarlo bien
# !sed -i 's/share=True, //' /content/GPT-SoVITS/webui.py
# !sed -i 's/share=is_share/share=True/g' /content/GPT-SoVITS/webui.py

# 2. Arreglar el error de la ruta (cambiar _ por -)
# !sed -i 's/GPT_SoVITS/GPT-SoVITS/g' /content/GPT-SoVITS/webui.py

print("¡Listo Tico! Errores corregidos. Ahora puedes continuar.")
# Out:
# ¡Listo Tico! Errores corregidos. Ahora puedes continuar.

# %%
# 1. Corregimos el error de sintaxis del 'share' y las rutas
# !sed -i 's/share=True, share=is_share/share=True/g' /content/GPT-SoVITS/webui.py
# !sed -i 's/GPT_SoVITS/GPT-SoVITS/g' /content/GPT-SoVITS/webui.py

# 2. Descargamos los modelos base (el cerebro) a la fuerza
print("Descargando modelos base... esto puede tardar un minuto.")
# !mkdir -p /content/GPT-SoVITS/GPT_SoVITS/pretrained_models
# !apt-get install -y aria2 > /dev/null
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/s1v2.ckpt -d /content/GPT-SoVITS/GPT_SoVITS/pretrained_models -o s1v2.ckpt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/s2G480k.pth -d /content/GPT-SoVITS/GPT_SoVITS/pretrained_models -o s2G480k.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/s2D480k.pth -d /content/GPT-SoVITS/GPT_SoVITS/pretrained_models -o s2D480k.pth

# 3. Lanzamos la interfaz de una vez
print("Encendiendo la máquina... busca el enlace azul abajo.")
# %cd /content/GPT-SoVITS
# !python webui.py
# Out:
# Descargando modelos base... esto puede tardar un minuto.
#
# 04/20 17:38:43 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/s1v2.ckpt
# Exception: [AbstractCommand.cc:351] errorCode=3 URI=https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/s1v2.ckpt
#   -> [HttpSkipResponseCommand.cc:218] errorCode=3 Resource not found
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# cce16c|ERR |       0B/s|/content/GPT-SoVITS/GPT_SoVITS/pretrained_models/s1v2.ckpt
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 04/20 17:38:43 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/s2G480k.pth
# ...

# %%
# 1. Arreglamos las carpetas rebeldes y el error de sintaxis
# !sed -i 's/share=True, share=is_share/share=True/g' /content/GPT-SoVITS/webui.py
# !sed -i 's/GPT_SoVITS/GPT-SoVITS/g' /content/GPT-SoVITS/webui.py

# 2. Descargamos el componente "Roberta" que falta (el que causa el pantallazo negro)
print("Descargando pieza faltante (Roberta)... esto es vital.")
# !mkdir -p /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# %cd /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# !wget -q https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/config.json
# !wget -q https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/pytorch_model.bin
# !wget -q https://huggingface.co/lj1995/GPT-SoVITS/resolve/main/chinese-roberta-wwm-ext-large/tokenizer.json

# 3. Encendemos la máquina otra vez
print("¡Listo! Encendiendo de nuevo. Busca el nuevo enlace azul.")
# %cd /content/GPT-SoVITS
# !python webui.py
# Out:
# Descargando pieza faltante (Roberta)... esto es vital.
# /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
# ¡Listo! Encendiendo de nuevo. Busca el nuevo enlace azul.
# /content/GPT-SoVITS
# ...
#     GPT_SoVITS/pretrained_models/v2Pro/s2Gv2Pro.pth
#     GPT_SoVITS/pretrained_models/v2Pro/s2Dv2Pro.pth
#     GPT_SoVITS/pretrained_models/s1v3.ckpt
#     GPT-SoVITS/pretrained_models/chinese-roberta-wwm-ext-large
#     GPT-SoVITS/pretrained_models/chinese-hubert-base
# /usr/bin/python3: can't open file '/content/GPT-SoVITS/GPT-SoVITS/download.py': [Errno 2] No such file or directory
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://943804249d8570965a.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from google.colab import drive
import os

# Esto fuerza a que salga la ventana de permiso
drive.mount('/content/drive', force_remount=True)

# Esto nos dirá qué carpetas ve la máquina ahora mismo
print("\n--- Carpetas encontradas en tu Drive ---")
if os.path.exists('/content/drive/MyDrive'):
    print(os.listdir('/content/drive/MyDrive'))
else:
    print("Drive no está montado todavía.")
# Out:
# Mounted at /content/drive
#
# --- Carpetas encontradas en tu Drive ---
# ['rvcDisconnected', 'Colab Notebooks', 'Opal', 'Mis Apps Publicadas', 'Gemini Gems', 'Be Good (JLY Edit Remix).mp3', 'Clonacion_JLC']

# %%
# !sed -i 's/app.queue().launch(/app.queue().launch(share=True, /' /content/GPT-SoVITS/webui.py

# %%
# !find /content -type f -name "requirements.txt" -exec sed -i '/opencc/d' {} +

# %%
# !apt-get update
# !apt-get install -y cmake libopencc-dev
# !pip install opencc-python-reimplemented
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...
